# %%
# Name :- Gaurav Karale
# UIN:- gkara2
# Date:- 21-11-2016
# Assignment12
import pandas as pd
import numpy as np

# %%
M = pd.read_csv("Movie_Review.csv", index_col='Name')

# %%
M.shape
# Out:
# (105, 16)

# %%
M
# Out:
#                     American Sniper  The Hunger Games: Mockingjay - Part 1  \
# Name
# Aarti Jaiswal                   4.0                                    NaN
# Aditya Dharmasagar              5.0                                    NaN
# Adrian Cavallaris               NaN                                    4.0
# Ahmed Muheebuddin               5.0                                    NaN
# Aishwarya reddy                 NaN                                    3.0
# Akhilesh                        NaN                                    NaN
# Andrew Webb                     4.0                                    3.0
# Anirudh                         3.0                                    4.0
# Anirudh Thota                   NaN                                    3.0
# anurag                          4.0                                    NaN
# Anusha Putta                    NaN                                    NaN
# ...

# %%
def pearson(s1, s2):
    """Take two pd.Series objects and return a pearson correlation."""
    s1_c = s1 - s1.mean()
    s2_c = s2 - s2.mean()
    return np.sum(s1_c * s2_c) / np.sqrt(np.sum(s1_c ** 2) * np.sum(s2_c ** 2))

# %%
def get_recs(movie_name, M, num):

    import numpy as np
    reviews = []
    for title in M.columns:
        if title == movie_name:
            continue
        cor = pearson(M[movie_name], M[title])
        if np.isnan(cor):
            continue
        else:
            reviews.append((title, cor))
    
    reviews.sort(key=lambda tup: tup[1], reverse=True)
    return reviews[:num]

# %% [markdown]
# ### Question 1:   What movie is most Similar to 'The fault in our stars' (60 pts)

# %%
record = get_recs('The Fault in Our Stars', M, 15)

# %%
record[:15]
# Out:
# [('Malificent', 0.23612859384417234),
#  ('Interstellar', 0.22999721967953585),
#  ('Divergent', 0.18022018783687657),
#  ('Unbroken', 0.15831054747081252),
#  ('Guardians of the Galaxy', 0.10977875826474735),
#  ('Gone Girl', 0.096135530667822086),
#  ('The Lego Movie', 0.069305404970375031),
#  ('How to Train your Dragon 2', 0.066061605425384057),
#  ('The Hunger Games: Mockingjay - Part 1', 0.051985878180909703),
#  ('Godzilla', 0.037355631401650762),
#  ('The Hobbit', 0.035965133181357814),
#  ('Transformers', 0.0062395975823337103),
#  ('300: Rise of an Empire', -0.025954362079744393),
#  ('American Sniper', -0.060869091243812311),
#  ('Big Hero 6', -0.2867806959695467)]

# %%
record[:1]
# Out:
# [('Malificent', 0.23612859384417234)]

# %% [markdown]
# ### Malificent is the movie most similar

# %% [markdown]
# ### Question 2:  Which movie(s) would you most like to see, based on your classmates experience? (40 pts)

# %%
#HINTS...

#the movies I've seen
my_ratings = M.ix['Gaurav Karale'].dropna()
#the movie I've rated the highest
my_ratings.sort(ascending=False)
#the name of the movie I've rated the highest
fav_movie = my_ratings.index[0]
# Out:
# /Users/gauravkarale/Documents/UIS_Studies/Data_Science/Anaconda/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:6: FutureWarning: sort is deprecated, use sort_values(inplace=True) for INPLACE sorting

# %%
fav_movie
# Out:
# '300: Rise of an Empire'

# %%
records = get_recs(fav_movie, M, 15)

# %%
records
# Out:
# [('Divergent', 0.29880439525455205),
#  ('American Sniper', 0.16350843032558637),
#  ('Malificent', 0.16276360922451519),
#  ('Transformers', 0.14461973783366711),
#  ('The Hobbit', 0.1378587749995788),
#  ('The Hunger Games: Mockingjay - Part 1', 0.092211048234563012),
#  ('How to Train your Dragon 2', 0.062387151650105714),
#  ('Unbroken', 0.055197646864445428),
#  ('Interstellar', 0.045875194649454692),
#  ('Godzilla', 0.040740638097673684),
#  ('Gone Girl', 0.015358333872813516),
#  ('The Fault in Our Stars', -0.025954362079744393),
#  ('Big Hero 6', -0.042084065381819233),
#  ('The Lego Movie', -0.089901618355160584),
#  ('Guardians of the Galaxy', -0.28037665593854155)]

# %% [markdown]
# ### Question 3: Bonus Question... For all the movies you haven't seen, can you predict how you'd rate them using your the class reviews? (10 pts)

# %%
notviewed = M.ix['Rajat Hatwar']
notviewed.sort()
for i in range(0, notviewed.count(), 1):
    notviewed.drop(notviewed.index[0], inplace=True)
# Out:
# /Users/gauravkarale/Documents/UIS_Studies/Data_Science/Anaconda/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: sort is deprecated, use sort_values(inplace=True) for INPLACE sorting
#   from ipykernel import kernelapp as app

# %%
notviewed
# Out:
# Gone Girl   NaN
# Name: Rajat Hatwar, dtype: float64

# %%
print "Pearson Correlation coefficient of :"
a= []
for i in range(0, M.shape[0], 1): 
    cor=pearson(M.ix[101], M.ix[i])
    print "(" + M.index[101] + " , " + M.index[i] + ") :", cor
    a.append(cor)
# Out:
# Pearson Correlation coefficient of :
# (Gaurav Karale , Aarti Jaiswal) : -0.254000254
# (Gaurav Karale , Aditya Dharmasagar) : 0.414780677892
# (Gaurav Karale , Adrian Cavallaris) : -1.11469074096e-17
# (Gaurav Karale , Ahmed Muheebuddin) : 0.254000254
# (Gaurav Karale , Aishwarya reddy) : 0.221709598189
# (Gaurav Karale , Akhilesh) : 0.465683302174
# (Gaurav Karale , Andrew Webb) : 0.0814104423603
# (Gaurav Karale , Anirudh) : -0.258198889747
# (Gaurav Karale , Anirudh Thota) : 0.374835686821
# (Gaurav Karale , anurag) : 0.217853484933
# (Gaurav Karale , Anusha Putta) : 0.0
# (Gaurav Karale , Arun Vedere) : 0.0342493872625
# (Gaurav Karale , Ashutosh Sureka) : -0.0750967493874
# (Gaurav Karale , Aswini kumar) : -0.0960030721475
# (Gaurav Karale , azam) : 0.0
# (Gaurav Karale , Benjamin Baysinger) : -0.00917740222124
# (Gaurav Karale , Bhuvana Posina) : 0.212218334444
# (Gaurav Karale , Bradley Brubaker) : -0.26940795304
# (Gaurav Karale , Brant Mullinix) : 0.180510120358
# ...

# %%
def pred_rate(x, a):
    """
    Takes two parameters 'x' and 'a'. 
    Where 'x' a list of rates given by classmates. 
    'a' is a array that has corresponding pearson correlation coefficientreturn (weights for the given rates).
    predicted rate is calculated as rate= (x[0]*a[0] + x[1]*a[1] +...+x[i]*a[i]) / (a[0]+a[1]+..+a[i]) 
    returns predicted rate 
    """
    j=0
    k=0
    for i in range(0, 23, 1): # as there are 23 rows(x.shape), range(0,23) 
        if x.irow(i)>0 and a[i]>0: 
            j= j+(a[i]*x.irow(i))
            k= k+a[i]
        else:
            continue
    return j/k

# %%
print "Based on class ratings, Following will be my ratings for those movies i did not rated "
for i in range(0, notviewed.shape[0], 1):
    x=M[notviewed.index[i]]
    rate=pred_rate(x, a)
    print notviewed.index[i] +": ", rate.round(1)
# Out:
# Based on class ratings, Following will be my ratings for those movies i did not rated
# Gone Girl:  4.1
# /Users/gauravkarale/Documents/UIS_Studies/Data_Science/Anaconda/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:12: FutureWarning: irow(i) is deprecated. Please use .iloc[i] or .iat[i]
# /Users/gauravkarale/Documents/UIS_Studies/Data_Science/Anaconda/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:13: FutureWarning: irow(i) is deprecated. Please use .iloc[i] or .iat[i]
