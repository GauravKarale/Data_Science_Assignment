# %%
# Titanic EDA Lab
# Gaurav Karale
# gkara2
# Data Science - Assignment Week 3
# September 11, 2016

# %%
import pandas as pd
% pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
titanicData=pd.read_csv("train.csv")

# %%
titanicData
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
# check for sequential data 
titanicData.PassengerId.value_counts()
# Out:
# 891    1
# 293    1
# 304    1
# 303    1
# 302    1
# 301    1
# 300    1
# 299    1
# 298    1
# 297    1
# 296    1
# 295    1
# 294    1
# 292    1
# 306    1
# 291    1
# 290    1
# 289    1
# 288    1
# 287    1
# 286    1
# 285    1
# 284    1
# 283    1
# 282    1
# 281    1
# 305    1
# 307    1
# 279    1
# 321    1
#       ..
# 561    1
# 560    1
# 584    1
# 585    1
# 586    1
# 587    1
# 610    1
# 609    1
# 608    1
# 607    1
# 606    1
# 605    1
# 604    1
# 603    1
# 602    1
# 601    1
# 600    1
# 599    1
# 598    1
# 597    1
# 596    1
# 595    1
# 594    1
# 593    1
# 592    1
# 591    1
# 590    1
# 589    1
# 588    1
# 1      1
# Name: PassengerId, dtype: int64

# %%
# as data is sequential, we will describe to check passanger count, mean, min, max, deviation   
titanicData.PassengerId.describe()
# Out:
# count    891.000000
# mean     446.000000
# std      257.353842
# min        1.000000
# 25%      223.500000
# 50%      446.000000
# 75%      668.500000
# max      891.000000
# Name: PassengerId, dtype: float64

# %%
#is null 
titanicData[titanicData.PassengerId.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
#Survived
titanicData.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
#Survived data based on sex for male 
titanicData[titanicData.Sex=='male'].Survived.value_counts().plot(kind='bar')
titanicData[titanicData.Sex=='female'].Survived.value_counts().plot(kind='bar')

# %%
#Survived data based on age(less than 15) and sex
fig, axs = plt.subplots(1,2)
titanicData[(titanicData.Age<15) & (titanicData.Sex=='male')].Survived.value_counts().plot(kind='barh', ax=axs[0], title="Male Survivor")
titanicData[(titanicData.Age<15) & (titanicData.Sex=='female')].Survived.value_counts().plot(kind='barh',ax=axs[1], title="Female Survivor")

# %%
#Survived data based on age(greater than 15) and sex
fig, axs = plt.subplots(1,2)
titanicData[(titanicData.Age>15) & (titanicData.Sex=='male')].Survived.value_counts().plot(kind='barh', ax=axs[0], title="Male Survivor")
titanicData[(titanicData.Age>15) & (titanicData.Sex=='female')].Survived.value_counts().plot(kind='barh',ax=axs[1], title="Female Survivor")

# %%
#Pclass 
titanicData.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
#pclass categories and number passanger travelling in that category
titanicData.Pclass.hist()

# %%
# male and female travelling in different classes
fig, axs = plt.subplots(1,2)
titanicData[titanicData.Sex=='male'].Pclass.value_counts().plot(kind='bar', ax=axs[0], title='Male travelling in class')
titanicData[titanicData.Sex=='female'].Pclass.value_counts().plot(kind='bar', ax=axs[1], title='Female travelling in class')

# %%
# survival rate of male and female travelling in different classes
fig, axs = plt.subplots(1,3)
titanicData[titanicData.Survived==1].Pclass.value_counts().plot(kind='bar', ax=axs[0], title='Common survival rate ')
titanicData[(titanicData.Sex=='female') & (titanicData.Survived==1)].Pclass.value_counts().plot(kind='bar',ax=axs[1],title='female')
titanicData[(titanicData.Sex=='male') & (titanicData.Survived==1)].Pclass.value_counts().plot(kind='bar',ax=axs[2], title=' male')

# %%
#Survival data based on age and class
fig, axs = plt.subplots(1,2)
titanicData[(titanicData.Survived==1) & (titanicData.Age>15)].Pclass.value_counts().plot(kind='bar', ax=axs[0], title='Survival rate for age > 15')
titanicData[(titanicData.Survived==1) & (titanicData.Age<15)].Pclass.value_counts().plot(kind='bar', ax=axs[1], title='Survival rate for age < 15')

# %%
#Name of person travelling
titanicData.Name.value_counts()
# Out:
# Graham, Mr. George Edward                                  1
# Elias, Mr. Tannous                                         1
# Madill, Miss. Georgette Alexandra                          1
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)        1
# Beane, Mrs. Edward (Ethel Clarke)                          1
# Roebling, Mr. Washington Augustus II                       1
# Moran, Mr. James                                           1
# Padro y Manent, Mr. Julian                                 1
# Scanlan, Mr. James                                         1
# Ali, Mr. William                                           1
# Weisz, Mrs. Leopold (Mathilde Francoise Pede)              1
# Abbing, Mr. Anthony                                        1
# Lahtinen, Mrs. William (Anna Sylfven)                      1
# Frost, Mr. Anthony Wood "Archie"                           1
# Lang, Mr. Fang                                             1
# ...

# %%
#Name of people survived
titanicData[titanicData.Survived==1].Name
# Out:
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 8      Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                    Nasser, Mrs. Nicholas (Adele Achem)
# 10                       Sandstrom, Miss. Marguerite Rut
# 11                              Bonnell, Miss. Elizabeth
# 15                      Hewlett, Mrs. (Mary D Kingcome)
# 17                          Williams, Mr. Charles Eugene
# 19                               Masselmani, Mrs. Fatima
# 21                                 Beesley, Mr. Lawrence
# 22                           McGowan, Miss. Anna "Annie"
# 23                          Sloper, Mr. William Thompson
# 25     Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# 28                         O'Dwyer, Miss. Ellen "Nellie"
# 31        Spencer, Mrs. William Augustus (Marie Eugenie)
# ...

# %%
#Name of people not survived
titanicData[titanicData.Survived==0].Name
# Out:
# 0                                Braund, Mr. Owen Harris
# 4                               Allen, Mr. William Henry
# 5                                       Moran, Mr. James
# 6                                McCarthy, Mr. Timothy J
# 7                         Palsson, Master. Gosta Leonard
# 12                        Saundercock, Mr. William Henry
# 13                           Andersson, Mr. Anders Johan
# 14                  Vestrom, Miss. Hulda Amanda Adolfina
# 16                                  Rice, Master. Eugene
# 18     Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 20                                  Fynney, Mr. Joseph J
# 24                         Palsson, Miss. Torborg Danira
# 26                               Emir, Mr. Farred Chehab
# 27                        Fortune, Mr. Charles Alexander
# 29                                   Todoroff, Mr. Lalio
# 30                              Uruchurtu, Don. Manuel E
# ...

# %%
#Histo based on sex
titanicData.Sex.value_counts().plot(kind='bar')

# %%
#EDA on age
titanicData.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
# 5       NaN
# 6      54.0
# 7       2.0
# 8      27.0
# 9      14.0
# 10      4.0
# 11     58.0
# 12     20.0
# 13     39.0
# 14     14.0
# 15     55.0
# 16      2.0
# 17      NaN
# 18     31.0
# 19      NaN
# 20     35.0
# 21     34.0
# 22     15.0
# 23     28.0
# 24      8.0
# 25     38.0
# 26      NaN
# 27     19.0
# 28      NaN
# 29      NaN
#        ...
# 861    21.0
# 862    48.0
# 863     NaN
# 864    24.0
# 865    42.0
# 866    27.0
# 867    31.0
# 868     NaN
# 869     4.0
# 870    26.0
# 871    47.0
# 872    33.0
# 873    47.0
# 874    28.0
# 875    15.0
# 876    20.0
# 877    19.0
# 878     NaN
# 879    56.0
# 880    25.0
# 881    33.0
# 882    22.0
# 883    28.0
# 884    25.0
# 885    39.0
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, dtype: float64

# %%
#calculate mean

avgAge=titanicData.Age.mean()

titanicData.Age=titanicData.Age.fillna(value=avgAge)
titanicData[titanicData.Age.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
#Age value having Nan is replaced with  avg value
 titanicData
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
#Survival data after null age replacement 
fig, axs = plt.subplots(1,2)
titanicData[(titanicData.Survived==1) & (titanicData.Age>15)].Pclass.value_counts().plot(kind='bar', ax=axs[0], title='Survival rate for age > 15')
titanicData[(titanicData.Survived==1) & (titanicData.Age<15)].Pclass.value_counts().plot(kind='bar', ax=axs[1], title='Survival rate for age < 15')
#observation number of ppl of class 1 survival no. got increase after replacement of null value for age

# %%
#min, max, deviation for age 
titanicData.Age.describe()
# Out:
# count    891.000000
# mean      29.699118
# std       13.002015
# min        0.420000
# 25%       22.000000
# 50%       29.699118
# 75%       35.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
#Class classification based on age
fig, axs = plt.subplots(1,2)
titanicData[(titanicData.Age>15)].Pclass.value_counts().plot(kind='bar', ax=axs[0], title='Number of ppl  age > 15')
titanicData[(titanicData.Age<15)].Pclass.value_counts().plot(kind='bar', ax=axs[1], title='Number of ppl  age < 15')

# %%
#EDA on Sib SP, Parch
#ppl who are travelling with family

titanicData[(titanicData.SibSp>0) | (titanicData.Parch >0)].Name.value_counts()
# Out:
# Allison, Miss. Helen Loraine                                 1
# Hamalainen, Mrs. William (Anna)                              1
# McCoy, Miss. Agnes                                           1
# Kiernan, Mr. Philip                                          1
# Panula, Master. Eino Viljami                                 1
# Frauenthal, Mrs. Henry William (Clara Heinsheimer)           1
# Skoog, Miss. Mabel                                           1
# Cardeza, Mr. Thomas Drake Martinez                           1
# Goldenberg, Mrs. Samuel L (Edwiga Grabowska)                 1
# Parrish, Mrs. (Lutie Davis)                                  1
# Crosby, Capt. Edward Gifford                                 1
# Collyer, Mr. Harvey                                          1
# Elias, Mr. Tannous                                           1
# Lahtinen, Mrs. William (Anna Sylfven)                        1
# Wick, Mrs. George Dennick (Mary Hitchcock)                   1
# ...

# %%
#ppl who are travelling alone
titanicData[(titanicData.SibSp==0) & (titanicData.Parch==0)]
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 11            12         1       1
# 12            13         0       3
# 14            15         0       3
# 15            16         1       2
# 17            18         1       2
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 30            31         0       1
# 32            33         1       3
# 33            34         0       2
# 36            37         1       3
# 37            38         0       3
# 42            43         0       3
# 44            45         1       3
# 45            46         0       3
# ...

# %%
#ppl who are not survived  and travelling alone
titanicData[(titanicData.SibSp==0) & (titanicData.Parch==0) & (titanicData.Survived==1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 11            12         1       1
# 15            16         1       2
# 17            18         1       2
# 19            20         1       3
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 28            29         1       3
# 32            33         1       3
# 36            37         1       3
# 44            45         1       3
# 47            48         1       3
# 55            56         1       1
# 56            57         1       2
# 61            62         1       1
# 66            67         1       2
# 74            75         1       3
# 79            80         1       3
# 81            82         1       3
# 82            83         1       3
# 84            85         1       2
# 106          107         1       3
# 107          108         1       3
# 123          124         1       2
# ...

# %%
#EDA on Ticket 
#list of  class 3 ticket
titanicData[titanicData.Pclass==3].Ticket
# Out:
# 0             A/5 21171
# 2      STON/O2. 3101282
# 4                373450
# 5                330877
# 7                349909
# 8                347742
# 10              PP 9549
# 12            A/5. 2151
# 13               347082
# 14               350406
# 16               382652
# 18               345763
# 19                 2649
# 22               330923
# 24               349909
# 25               347077
# 26                 2631
# 28               330959
# 29               349216
# 32               335677
# 36                 2677
# 37           A./5. 2152
# 38               345764
# 39                 2651
# 40                 7546
# 42               349253
# 44               330958
# 45      S.C./A.4. 23567
# 46               370371
# 47                14311
#              ...
# 837              392092
# 838                1601
# 840    SOTON/O2 3101287
# 843                2683
# 844              315090
# 845           C.A. 5547
# 846            CA. 2343
# ...

# %%
#list of  class 2 ticket
titanicData[titanicData.Pclass==2].Ticket
# Out:
# 9                237736
# 15               248706
# 17               244373
# 20               239865
# 21               248698
# 33           C.A. 24579
# 41                11668
# 43        SC/Paris 2123
# 53                 2926
# 56           C.A. 31026
# 58           C.A. 34651
# 66           C.A. 29395
# 70           C.A. 33111
# 72         S.O.C. 14879
# 78               248738
# 84           SO/C 14885
# 98               231919
# 99               244367
# 117               11668
# 120        S.O.C. 14879
# 122              237736
# 123               27267
# 133              228414
# 134          C.A. 29178
# 135       SC/PARIS 2133
# 144              231945
# 145          C.A. 33112
# 148              230080
# 149              244310
# 150         S.O.P. 1166
#              ...
# 732              239855
# 733               28425
# 734              233639
# 747              250648
# 750               29103
# 754              220845
# 755              250649
# ...

# %%
#list of  class 1 ticket
titanicData[titanicData.Pclass==1].Ticket
# Out:
# 1         PC 17599
# 3           113803
# 6            17463
# 11          113783
# 23          113788
# 27           19950
# 30        PC 17601
# 31        PC 17569
# 34        PC 17604
# 35          113789
# 52        PC 17572
# 54          113509
# 55           19947
# 61          113572
# 62           36973
# 64        PC 17605
# 83          113059
# 88           19950
# 92     W.E.P. 5734
# 96        PC 17754
# 97        PC 17759
# 102          35281
# 110         110465
# 118       PC 17558
# 124          35281
# 136          11752
# 137         113803
# 139       PC 17593
# 151         113776
# 155       PC 17597
#           ...
# 763         113760
# 765          13502
# 766         112379
# 779          24160
# 781          17474
# 782         113501
# 789       PC 17593
# 793       PC 17600
# 796          17465
# 802         113760
# 806         112050
# 809         113806
# 815         112058
# 820          12749
# 822          19972
# 829         113572
# ...

# %%
#EDA for fare
titanicData.Fare.value_counts()
# Out:
# 8.0500      43
# 13.0000     42
# 7.8958      38
# 7.7500      34
# 26.0000     31
# 10.5000     24
# 7.9250      18
# 7.7750      16
# 7.2292      15
# 26.5500     15
# 0.0000      15
# 8.6625      13
# 7.8542      13
# 7.2500      13
# 7.2250      12
# 9.5000       9
# 16.1000      9
# 15.5000      8
# 24.1500      8
# 14.5000      7
# 7.0500       7
# 56.4958      7
# 52.0000      7
# 69.5500      7
# 31.2750      7
# 14.4542      7
# 27.9000      6
# 7.7958       6
# 30.0000      6
# 26.2500      6
#             ..
# 6.9500       1
# 15.0500      1
# 21.6792      1
# 7.1417       1
# 15.0458      1
# 4.0125       1
# 12.0000      1
# 8.4583       1
# 7.7875       1
# 14.0000      1
# 15.0000      1
# 9.8417       1
# 12.2750      1
# 12.2875      1
# 22.5250      1
# 6.4500       1
# 15.5500      1
# 8.5167       1
# 63.3583      1
# 6.8583       1
# 22.0250      1
# 13.7917      1
# 221.7792     1
# 12.6500      1
# 8.8500       1
# 61.1750      1
# 10.1708      1
# ...

# %%
#mean, max, min, devia calculation
titanicData.Fare.describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
# null value check
titanicData[titanicData.Fare.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
#Passangers who were travelling for free
titanicData[titanicData.Fare==0]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# ...

# %%
#Passangers who were travelling free in first class
titanicData[(titanicData.Fare==0) & (titanicData.Pclass==1)]
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 263          264         0       1            Harrison, Mr. William  male
# 633          634         0       1    Parr, Mr. William Henry Marsh  male
# 806          807         0       1           Andrews, Mr. Thomas Jr  male
# 815          816         0       1                 Fry, Mr. Richard  male
# 822          823         0       1  Reuchlin, Jonkheer. John George  male
#
#            Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 263  40.000000      0      0  112059   0.0   B94        S
# 633  29.699118      0      0  112052   0.0   NaN        S
# 806  39.000000      0      0  112050   0.0   A36        S
# 815  29.699118      0      0  112058   0.0  B102        S
# 822  38.000000      0      0   19972   0.0   NaN        S

# %%
#Passangers with highest fare
titanicData[titanicData.Fare==512.329200]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
#Passangers who are travelling for free and did not survive
titanicData[(titanicData.Fare==0) & (titanicData.Survived==0)]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# 732          733         0       2              Knight, Mr. Robert J  male
# ...

# %%
#EDA on Cabin
titanicData.Cabin.value_counts()
# Out:
# C23 C25 C27        4
# G6                 4
# B96 B98            4
# D                  3
# C22 C26            3
# E101               3
# F2                 3
# F33                3
# B57 B59 B63 B66    2
# C68                2
# B58 B60            2
# E121               2
# D20                2
# E8                 2
# E44                2
# B77                2
# C65                2
# D26                2
# E24                2
# E25                2
# B20                2
# C93                2
# D33                2
# E67                2
# D35                2
# D36                2
# C52                2
# F4                 2
# C125               2
# C124               2
#                   ..
# F G63              1
# A6                 1
# D45                1
# D6                 1
# D56                1
# C101               1
# C54                1
# D28                1
# D37                1
# B102               1
# D30                1
# E17                1
# ...

# %%
titanicData[titanicData.Cabin.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 30            31         0       1
# 32            33         1       3
# 33            34         0       2
# ...

# %%
# count,frequency calculation 
titanicData.Cabin.describe()
# Out:
# count             204
# unique            147
# top       C23 C25 C27
# freq                4
# Name: Cabin, dtype: object

# %%
#EDA on embarked column 
titanicData.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
titanicData[titanicData.Embarked.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
#count, freq calculation 
titanicData.Embarked.describe()
# Out:
# count     889
# unique      3
# top         S
# freq      644
# Name: Embarked, dtype: object

# %%
# replaced NA values with most common value 'S'
titanicData.Embarked=titanicData.Embarked.fillna('S')

# %%
#Passenger with embarked as S  
fig, axs = plt.subplots(1,2)
titanicData[titanicData.Embarked=='S'].Pclass.value_counts().plot(kind='bar',ax=axs[0],title='Passanger embarked=S ')
titanicData[titanicData.Embarked=='S'].Survived.value_counts().plot(kind='bar',ax=axs[1],title='Survived with embarked =S ')

# %%
#Passenger with embarked as C 
fig, axs = plt.subplots(1,2)
titanicData[titanicData.Embarked=='C'].Pclass.value_counts().plot(kind='bar',ax=axs[0],title='Passanger embarked=C ')
titanicData[titanicData.Embarked=='C'].Survived.value_counts().plot(kind='bar',ax=axs[1],title='Survived with embarked =C ')

# %%
#Passenger with embarked as Q 
fig, axs = plt.subplots(1,2)
titanicData[titanicData.Embarked=='Q'].Pclass.value_counts().plot(kind='bar',ax=axs[0],title='Passanger embarked=Q ')
titanicData[titanicData.Embarked=='Q'].Survived.value_counts().plot(kind='bar',ax=axs[1],title='Survived with embarked =Q')
